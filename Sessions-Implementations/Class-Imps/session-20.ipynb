# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Iran_COVID.csv')
df.head(3)
# Out:
#    Unnamed: 0     dateRep  day  month  year  cases  deaths  \
# 0       24461  2020-11-12   12     11  2020  11780     462
# 1       24462  2020-11-11   11     11  2020  10339     453
# 2       24463  2020-11-10   10     11  2020  10463     458
#
#   countriesAndTerritories geoId countryterritoryCode  popData2019  \
# 0                    Iran    IR                  IRN   82913893.0
# 1                    Iran    IR                  IRN   82913893.0
# 2                    Iran    IR                  IRN   82913893.0
#
#   continentExp         CNC
# 0         Asia  152.471432
# 1         Asia  146.494147
# 2         Asia  142.428483

# %%
df=df.drop(['Unnamed: 0','countriesAndTerritories','geoId','countryterritoryCode','popData2019','continentExp',
    'CNC'],
          axis=1)
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths
# 0  2020-11-12   12     11  2020  11780     462
# 1  2020-11-11   11     11  2020  10339     453
# 2  2020-11-10   10     11  2020  10463     458
# 3  2020-11-09    9     11  2020   9236     459
# 4  2020-11-08    8     11  2020   9450     423

# %%
df.loc[df.duplicated(subset=['cases','deaths'],keep='last')]
# Out:
#         dateRep  day  month  year  cases  deaths
# 79   2020-08-25   25      8  2020      0       0
# 84   2020-08-20   20      8  2020      0       0
# 222  2020-04-04    4      4  2020      0       0
# 267  2020-02-19   19      2  2020      0       0
# 268  2020-02-18   18      2  2020      0       0
# 269  2020-02-17   17      2  2020      0       0
# 270  2020-02-16   16      2  2020      0       0
# 271  2020-02-15   15      2  2020      0       0
# 272  2020-02-14   14      2  2020      0       0
# 273  2020-02-13   13      2  2020      0       0
# 274  2020-02-12   12      2  2020      0       0
# 275  2020-02-11   11      2  2020      0       0
# 276  2020-02-10   10      2  2020      0       0
# 277  2020-02-09    9      2  2020      0       0
# 278  2020-02-08    8      2  2020      0       0
# 279  2020-02-07    7      2  2020      0       0
# 280  2020-02-06    6      2  2020      0       0
# 281  2020-02-05    5      2  2020      0       0
# ...

# %%
df.drop(df.loc[df.duplicated(keep='first')].index)
# Out:
#         dateRep  day  month  year  cases  deaths
# 0    2020-11-12   12     11  2020  11780     462
# 1    2020-11-11   11     11  2020  10339     453
# 2    2020-11-10   10     11  2020  10463     458
# 3    2020-11-09    9     11  2020   9236     459
# 4    2020-11-08    8     11  2020   9450     423
# ..          ...  ...    ...   ...    ...     ...
# 313  2020-01-04    4      1  2020      0       0
# 314  2020-01-03    3      1  2020      0       0
# 315  2020-01-02    2      1  2020      0       0
# 316  2020-01-01    1      1  2020      0       0
# 317  2019-12-31   31     12  2019      0       0
#
# [318 rows x 6 columns]

# %%
df.drop_duplicates(keep='first',inplace=True,ignore_index=True)

# %%
df.loc[df.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [dateRep, day, month, year, cases, deaths]
# Index: []

# %%
df.sum(axis=0)
# Out:
# dateRep    2020-11-122020-11-112020-11-102020-11-092020-1...
# day                                                     4915
# month                                                   1826
# year                                                  642359
# cases                                                 715068
# deaths                                                 39664
# dtype: object

# %%
#how  many non-null
df.count()
# Out:
# dateRep    318
# day        318
# month      318
# year       318
# cases      318
# deaths     318
# dtype: int64

# %%
df.shape
# Out:
# (318, 6)

# %%
df.cumsum()
# Out:
#                                                dateRep   day  month    year  \
# 0                                           2020-11-12    12     11    2020
# 1                                 2020-11-122020-11-11    23     22    4040
# 2                       2020-11-122020-11-112020-11-10    33     33    6060
# 3             2020-11-122020-11-112020-11-102020-11-09    42     44    8080
# 4    2020-11-122020-11-112020-11-102020-11-092020-1...    50     55   10100
# ..                                                 ...   ...    ...     ...
# 313  2020-11-122020-11-112020-11-102020-11-092020-1...  4878   1811  634280
# 314  2020-11-122020-11-112020-11-102020-11-092020-1...  4881   1812  636300
# 315  2020-11-122020-11-112020-11-102020-11-092020-1...  4883   1813  638320
# 316  2020-11-122020-11-112020-11-102020-11-092020-1...  4884   1814  640340
# 317  2020-11-122020-11-112020-11-102020-11-092020-1...  4915   1826  642359
#
#       cases  deaths
# 0     11780     462
# ...

# %%
plt.plot(df.cases.cumsum(skipna=True))

# %%
df.cases.max()
# Out:
# 11780

# %%
df.cases.idxmax()
# Out:
# 0

# %%
df.deaths.mean()/24
# Out:
# 5.19706498951782

# %%
df.deaths.median()/24
# Out:
# 4.854166666666667

# %%
df.describe()
# Out:
#               day       month         year         cases      deaths
# count  318.000000  318.000000   318.000000    318.000000  318.000000
# mean    15.455975    5.742138  2019.996855   2248.641509  124.729560
# std      8.891367    3.027141     0.056077   2031.042694  108.079109
# min      1.000000    1.000000  2019.000000      0.000000    0.000000
# 25%      8.000000    3.000000  2020.000000   1011.500000   48.000000
# 50%     15.000000    6.000000  2020.000000   2159.000000  116.500000
# 75%     23.000000    8.000000  2020.000000   2663.250000  183.750000
# max     31.000000   12.000000  2020.000000  11780.000000  462.000000

# %% [markdown]
# # percent Change

# %%
plt.plot(df.deaths.pct_change(periods=30))

# %%
df.corr()
# Out:
#              day     month      year     cases    deaths
# day     1.000000 -0.049648 -0.098344 -0.025189  0.012806
# month  -0.049648  1.000000 -0.116291  0.778013  0.799328
# year   -0.098344 -0.116291  1.000000  0.062281  0.064921
# cases  -0.025189  0.778013  0.062281  1.000000  0.918798
# deaths  0.012806  0.799328  0.064921  0.918798  1.000000

# %%
plt.scatter(df.cases,df.deaths)

# %%
df.dateRep[0]
# Out:
# '2020-11-12'

# %%
# !python -m pip install persiantools
# Out:
# ...
#   Using cached persiantools-1.5.1-py3-none-any.whl (13 kB)
# ...

# %%
from persiantools.jdatetime import JalaliDate

# %%
JalaliDate.to_jalali(2020,11,12)
# Out:
# JalaliDate(1399, 8, 22, Panjshanbeh)

# %%
def my_function(in_str):
    year=int(in_str[:4])
    month=int(in_str[5:7])
    day=int(in_str[7:])
    return JalaliDate.to_jalali(year,month,day)

# %%
df.dateRep.apply(my_function)
# Out:
# 0      1399-07-28
# 1      1399-07-29
# 2      1399-07-30
# 3      1399-08-01
# 4      1399-08-02
#           ...
# 313    1398-10-06
# 314    1398-10-07
# 315    1398-10-08
# 316    1398-10-09
# 317    1398-08-08
# Name: dateRep, Length: 318, dtype: object

# %%
df.dateRep.apply(lambda x:JalaliDate.to_jalali(int(x[:4]),int(x[5:7]),int(x[7:])))
# Out:
# 0      1399-07-28
# 1      1399-07-29
# 2      1399-07-30
# 3      1399-08-01
# 4      1399-08-02
#           ...
# 313    1398-10-06
# 314    1398-10-07
# 315    1398-10-08
# 316    1398-10-09
# 317    1398-08-08
# Name: dateRep, Length: 318, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dateRep  318 non-null    object
#  1   day      318 non-null    int64
#  2   month    318 non-null    int64
#  3   year     318 non-null    int64
#  4   cases    318 non-null    int64
#  5   deaths   318 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 15.0+ KB
